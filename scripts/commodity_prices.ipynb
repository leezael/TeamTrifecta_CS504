# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #library used to create visualizations
import csv

# %%
#read file
filename = '/Users/dcolu/OneDrive/Documents/GitHub/TeamTrifecta_CS504/scripts/data/commodity_prices.csv'
df = pd.read_csv(filename, encoding = "ISO-8859-1")
df.head()
# Out:
#        Date     Amount Commodity
# 0  1/1/2018  75.782609   IronOre
# 1  2/1/2018  77.650000   IronOre
# 2  3/1/2018  71.318182   IronOre
# 3  4/1/2018  66.333333   IronOre
# 4  5/1/2018  66.630435   IronOre

# %%
#explore data
df['Commodity'].value_counts()
# Out:
# CrudePetroleum      57
# StainlessSteel      57
# CastIron            57
# Slag                57
# Gas                 57
# Nickel              57
# Steel               57
# RefinedPetroleum    57
# IronOre             56
# Aluminium           56
# Coal                56
# Corn                56
# Wheat               56
# SunflowerOil        56
# Barley              56
# RapeseedOil         56
# Copper              56
# Name: Commodity, dtype: int64

# %%
#create bar chart
title=("Types of Commodities")
df.Commodity.value_counts().plot(kind='bar',title=title)
# Out:
# <AxesSubplot: title={'center': 'Types of Commodities'}>
